# %% [markdown]
# <h2>Носов Александр Сергеевич<br>
# Задача 1.1<h2>

# %%
import math
m_square = matrix([[0,0], [1,0], [1,1], [0,1], [0,0]])
angle = 0
angle = math.radians(angle)
m_rot_square_1 = matrix([[cos(angle), sin(angle)], [-sin(angle), cos(angle)]])
angle = 40
angle = math.radians(angle)
m_rot_square_2 = matrix([[cos(angle), sin(angle)], [-sin(angle), cos(angle)]])

# %%
show(line(m_square * m_rot_square_1) + line(m_square * m_rot_square_2), aspect_ratio = 1)
# Out:
# Graphics object consisting of 2 graphics primitives
